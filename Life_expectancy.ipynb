# %%
import pandas as pd
df = pd.read_excel('file:///C:/Users/HP/AppData/Roaming/Microsoft/Windows/Network%20Shortcuts/life%20expectancy.xlsx')

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy (men)  \
# 0  Afghanistan  2015  Developing                     70
# 1  Afghanistan  2014  Developing                     59
# 2  Afghanistan  2013  Developing                     79
# 3  Afghanistan  2012  Developing                     65
# 4  Afghanistan  2011  Developing                     76
#
#    Life expectancy(women)  Adult Mortality (men)  Adult Mortality (women)  \
# 0                      66                     67                       65
# 1                      67                     73                       85
# 2                      51                     87                       67
# 3                      81                     63                       91
# 4                      75                     57                       72
#
#    Infant deaths  Alcohol  Percentage expenditure  ...  Polio  \
# 0             62     0.01               71.279624  ...    6.0
# ...

# %%
filtered_dataset1 = df[(df['Year'] == 2010) | (df['Year'] == 2000)]

# %%
filtered_dataset1.head()
# Out:
#                 Country  Year      Status  Life expectancy (men)  \
# 5           Afghanistan  2010  Developing                     51
# 15          Afghanistan  2000  Developing                     56
# 21              Albania  2010  Developing                     54
# 31              Albania  2000  Developing                     58
# 37              Algeria  2010  Developing                     69
# ..                  ...   ...         ...                    ...
# 768            Djibouti  2000  Developing                     57
# 775  Dominican Republic  2010  Developing                     66
# 785  Dominican Republic  2000  Developing                     76
# 791             Ecuador  2010  Developing                     51
# 801             Ecuador  2000  Developing                     53
#
#      Life expectancy(women)  Adult Mortality (men)  Adult Mortality (women)  \
# 5                        77                     71                       57
# ...

# %%
filtered_dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 366 entries, 5 to 2937
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          366 non-null    object
#  1   Year                             366 non-null    int64
#  2   Status                           366 non-null    object
#  3   Life expectancy (men)            366 non-null    int64
#  4   Life expectancy(women)           366 non-null    int64
#  5   Adult Mortality (men)            366 non-null    int64
#  6   Adult Mortality (women)          366 non-null    int64
#  7   Infant deaths                    366 non-null    int64
#  8   Alcohol                          364 non-null    float64
#  9   Percentage expenditure           366 non-null    float64
#  10  Hepatitis B(men)                 366 non-null    int64
#  11  Hepatitis B(women)               366 non-null    int64
# ...

# %%
filtered_dataset1.describe()
# Out:
#               Year  Life expectancy (men)  Life expectancy(women)  \
# count   366.000000             366.000000              366.000000
# mean   2005.000000              67.844262               67.576503
# std       5.006845              10.962217               10.158384
# min    2000.000000              50.000000               50.000000
# 25%    2000.000000              58.000000               59.000000
# 50%    2005.000000              68.000000               67.000000
# 75%    2010.000000              78.000000               75.750000
# max    2010.000000              85.000000               85.000000
#
#        Adult Mortality (men)  Adult Mortality (women)  Infant deaths  \
# count             366.000000               366.000000     366.000000
# mean               73.964481                74.103825      32.734973
# std                14.506733                14.462238     128.574857
# min                50.000000                50.000000       0.000000
# ...

# %%
df1 = filtered_dataset1
